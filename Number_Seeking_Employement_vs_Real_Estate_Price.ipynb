# %%
import matplotlib as mpl
# mpl.use('TkAgg')
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from statsmodels.tsa.stattools import grangercausalitytests
import numpy as np
from sklearn.preprocessing import MinMaxScaler
# %matplotlib inline

# %% [markdown]
# ## Data Exploration

# %%
# Take a look into csv file
df = pd.read_csv('data/data.csv')
df.date = pd.to_datetime(df.date, format='%Y%m')
df.index = df.date

# %%
df.head()
# Out:
#                  date  gangnam_price  gangbook_price  \
# date
# 2013-01-01 2013-01-01         526716          368940
# 2013-02-01 2013-02-01         525056          367773
# 2013-03-01 2013-03-01         528064          367142
# 2013-04-01 2013-04-01         530252          366278
# 2013-05-01 2013-05-01         531736          366451
#
#             Seeking_jobs_in_Seoul_numbers
# date
# 2013-01-01                         4247.0
# 2013-02-01                         4247.0
# 2013-03-01                         4247.0
# 2013-04-01                         5561.0
# 2013-05-01                         5561.0

# %%
# modifying data
df.Seeking_jobs_in_Seoul_numbers = df.Seeking_jobs_in_Seoul_numbers[:'2018-01-01']
df.gangbook_price = df.gangbook_price[:'2018-01-01']
df.gangnam_price = df.gangnam_price[:'2018-01-01']
df['Seeking_jobs_gradient'] = np.gradient(df.Seeking_jobs_in_Seoul_numbers)
df.head()
# Out:
#                  date  gangnam_price  gangbook_price  \
# date
# 2013-01-01 2013-01-01       526716.0        368940.0
# 2013-02-01 2013-02-01       525056.0        367773.0
# 2013-03-01 2013-03-01       528064.0        367142.0
# 2013-04-01 2013-04-01       530252.0        366278.0
# 2013-05-01 2013-05-01       531736.0        366451.0
#
#             Seeking_jobs_in_Seoul_numbers  Seeking_jobs_gradient
# date
# 2013-01-01                         4247.0                    0.0
# 2013-02-01                         4247.0                    0.0
# 2013-03-01                         4247.0                  657.0
# 2013-04-01                         5561.0                  657.0
# 2013-05-01                         5561.0                    0.0

# %%
# plotting
fig = plt.figure(figsize=[15, 7])
plt.suptitle('Seeking Employement vs Real Estate Price', fontsize=22)
plt.subplot(211)
plt.plot(df.Seeking_jobs_in_Seoul_numbers, 'red')
plt.legend()

plt.subplot(212)
gangbook_price, = plt.plot(df.gangbook_price, 'b')
plt.tick_params(axis='y')
plt.twinx()
gangnam_price, =plt.plot(df.gangnam_price, 'g')
plt.tick_params(axis='y')
plt.legend(handles=[gangnam_price, gangbook_price])
plt.tight_layout()
plt.show()

# %% [markdown]
# observation: gangnam and ganbook real real estate has a strong positive relationship

# %%
sns.factorplot('Seeking_jobs_in_Seoul_numbers','gangnam_price', data=df, size=6, aspect=2)
plt.show()

# %%
sns.factorplot('Seeking_jobs_gradient','gangnam_price', data=df, size=6, aspect=2)
plt.show()

# %% [markdown]
# Observation: Number of Employeement and real estate prices itself does not show clear relationship

# %% [markdown]
# ## Using Statistics Tools

# %%
def normalization(array):
    """ scale data to 0~1"""

    y = np.array(array)
    y = y.reshape(-1, 1)
    min_max_scaler = MinMaxScaler()
    y = min_max_scaler.fit_transform(y)
    # checking if array contains NaN
    numpy_1 = np.array(array)
    if np.isnan(numpy_1).any():
        return None
    return y

# find prior event
def granger(array1, array2):
    df = pd.DataFrame(normalization(array1))
    df['1'] = pd.DataFrame(normalization(array2))


    granger = grangercausalitytests(df, maxlag=18, verbose=True)
    min = 10
    best_lag = 0
    for i in granger:
        p_value = granger[i][0]['ssr_ftest'][1]
        if p_value < min:
            min = p_value
            best_lag = i
    return min, best_lag

# %%
#cleaning input data for def granger():
df = pd.read_csv('data/data.csv')
date = df['date'].values
gangnam_price = df['gangnam_price'].values
Seeking_jobs = df['Seeking_jobs_in_Seoul_numbers'].values
Seeking_jobs = Seeking_jobs[np.logical_not(np.isnan(Seeking_jobs))]
min = min([len(Seeking_jobs), len(gangnam_price)])
Seeking_jobs = Seeking_jobs[:min]
gangnam_price = gangnam_price[:min]

# %% [markdown]
# Null Hypothesis: There is no such relationship

# %%
granger(gangnam_price, Seeking_jobs)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.0258  , p=0.3155  , df_denom=56, df_num=1
# ssr based chi2 test:   chi2=1.0808  , p=0.2985  , df=1
# likelihood ratio test: chi2=1.0710  , p=0.3007  , df=1
# parameter F test:         F=1.0258  , p=0.3155  , df_denom=56, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.8202  , p=0.0282  , df_denom=53, df_num=2
# ssr based chi2 test:   chi2=8.3612  , p=0.0153  , df=2
# likelihood ratio test: chi2=7.8108  , p=0.0201  , df=2
# parameter F test:         F=3.8202  , p=0.0282  , df_denom=53, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.4308  , p=0.0760  , df_denom=50, df_num=3
# ssr based chi2 test:   chi2=8.3134  , p=0.0400  , df=3
# likelihood ratio test: chi2=7.7603  , p=0.0512  , df=3
# parameter F test:         F=2.4308  , p=0.0760  , df_denom=50, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.8749  , p=0.1306  , df_denom=47, df_num=4
# ssr based chi2 test:   chi2=8.9356  , p=0.0627  , df=4
# likelihood ratio test: chi2=8.2905  , p=0.0815  , df=4
# parameter F test:         F=1.8749  , p=0.1306  , df_denom=47, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.9439  , p=0.1062  , df_denom=44, df_num=5
# ssr based chi2 test:   chi2=12.1494 , p=0.0328  , df=5
# likelihood ratio test: chi2=10.9773 , p=0.0518  , df=5
# parameter F test:         F=1.9439  , p=0.1062  , df_denom=44, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.5686  , p=0.1809  , df_denom=41, df_num=6
# ssr based chi2 test:   chi2=12.3959 , p=0.0537  , df=6
# likelihood ratio test: chi2=11.1592 , p=0.0836  , df=6
# parameter F test:         F=1.5686  , p=0.1809  , df_denom=41, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.2619  , p=0.2949  , df_denom=38, df_num=7
# ssr based chi2 test:   chi2=12.3197 , p=0.0905  , df=7
# likelihood ratio test: chi2=11.0771 , p=0.1353  , df=7
# parameter F test:         F=1.2619  , p=0.2949  , df_denom=38, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.3605  , p=0.2477  , df_denom=35, df_num=8
# ssr based chi2 test:   chi2=16.1701 , p=0.0400  , df=8
# likelihood ratio test: chi2=14.0796 , p=0.0797  , df=8
# parameter F test:         F=1.3605  , p=0.2477  , df_denom=35, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.1778  , p=0.3418  , df_denom=32, df_num=9
# ssr based chi2 test:   chi2=16.8944 , p=0.0504  , df=9
# likelihood ratio test: chi2=14.5925 , p=0.1028  , df=9
# parameter F test:         F=1.1778  , p=0.3418  , df_denom=32, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.1234  , p=0.3790  , df_denom=29, df_num=10
# ssr based chi2 test:   chi2=19.3689 , p=0.0358  , df=10
# likelihood ratio test: chi2=16.3708 , p=0.0895  , df=10
# parameter F test:         F=1.1234  , p=0.3790  , df_denom=29, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.4852  , p=0.1965  , df_denom=26, df_num=11
# ssr based chi2 test:   chi2=30.7885 , p=0.0012  , df=11
# likelihood ratio test: chi2=23.8904 , p=0.0132  , df=11
# parameter F test:         F=1.4852  , p=0.1965  , df_denom=26, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.1913  , p=0.3451  , df_denom=23, df_num=12
# ssr based chi2 test:   chi2=29.8343 , p=0.0030  , df=12
# likelihood ratio test: chi2=23.2023 , p=0.0261  , df=12
# parameter F test:         F=1.1913  , p=0.3451  , df_denom=23, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.0039  , p=0.4826  , df_denom=20, df_num=13
# ssr based chi2 test:   chi2=30.6701 , p=0.0038  , df=13
# likelihood ratio test: chi2=23.6092 , p=0.0349  , df=13
# parameter F test:         F=1.0039  , p=0.4826  , df_denom=20, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=0.8966  , p=0.5767  , df_denom=17, df_num=14
# ssr based chi2 test:   chi2=33.9657 , p=0.0021  , df=14
# likelihood ratio test: chi2=25.4360 , p=0.0305  , df=14
# parameter F test:         F=0.8966  , p=0.5767  , df_denom=17, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=0.8505  , p=0.6214  , df_denom=14, df_num=15
# ssr based chi2 test:   chi2=41.0043 , p=0.0003  , df=15
# likelihood ratio test: chi2=29.1481 , p=0.0154  , df=15
# parameter F test:         F=0.8505  , p=0.6214  , df_denom=14, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=1.3061  , p=0.3321  , df_denom=11, df_num=16
# ssr based chi2 test:   chi2=83.5890 , p=0.0000  , df=16
# likelihood ratio test: chi2=46.8435 , p=0.0001  , df=16
# parameter F test:         F=1.3061  , p=0.3321  , df_denom=11, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=1.2994  , p=0.3661  , df_denom=8, df_num=17
# ssr based chi2 test:   chi2=118.7315, p=0.0000  , df=17
# likelihood ratio test: chi2=56.9637 , p=0.0000  , df=17
# parameter F test:         F=1.2994  , p=0.3661  , df_denom=8, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=2.0629  , p=0.2169  , df_denom=5, df_num=18
# ssr based chi2 test:   chi2=311.9089, p=0.0000  , df=18
# likelihood ratio test: chi2=89.5175 , p=0.0000  , df=18
# parameter F test:         F=2.0629  , p=0.2169  , df_denom=5, df_num=18
# (0.02819124506226828, 2)

# %% [markdown]
# #### Interpretation

# %% [markdown]
# Using ssr based F test, we cannot reject the null hypothesis since p > .01
#
# But, p is close enough to .01 meaning the correlations are not ordinary.
#
# Still, Number of Seeking Employment is NOT a direct cause or a prior event to Seoul real estate price.
